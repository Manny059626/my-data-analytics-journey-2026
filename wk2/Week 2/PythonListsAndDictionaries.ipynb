# %%
# Exercise 1: Lists and Dictionaries

"""
Instructions:
1. Create a shopping list with at least 5 items
2. Print out the third item in the list
3. Replace the first item with a different item
4. Add an item to the end of the list
5. Create a dictionary of 3 grocery items with their prices
6. Print a message showing one item and its price
7. Add a new item to the dictionary with its price
8. Calculate and print the total cost of all items
"""

# %% [markdown]
# # Shopping list for Clothes

# %%
shopping_list= ["shirts", "sweater", "socks", "shoes", "hats"]

# %%
print(f"the third item in my shopping list is: {shopping_list[2]}")
# Out:
# the third item in my shopping list is: socks

# %%
print("the third item:", shopping_list[2])
# Out:
# the third item: socks

# %%
print(f"updated shopping list: {shopping_list}")
# Out:
# updated shopping list: ['sweater', 'sweater', 'socks', 'shoes', 'hats']

# %%
shopping_list[0]= "sweater"

# %%
print("Updated shopping list:", shopping_list)
# Out:
# Updated shopping list: ['sweater', 'sweater', 'socks', 'shoes', 'hats']

# %%
shopping_list.append("jeans")

# %%
print("Updated shopping list:", shopping_list)
# Out:
# Updated shopping list: ['sweater', 'sweater', 'socks', 'shoes', 'hats', 'jeans']

# %%
shopping_list.append("tie")

# %%
print(f"shopping list after adding an item: {shopping_list}")
# Out:
# shopping list after adding an item: ['sweater', 'sweater', 'socks', 'shoes', 'hats', 'jeans', 'tie']

# %% [markdown]
# Clothes Prices

# %%
clothes_prices = {"shoes": 29.99, "jeans": 19.99, "socks": 7.99}

# %%
print(f"the price of shoes is ${clothes_prices['shoes']}")
# Out:
# the price of shoes is $29.99

# %%
print("socks costs:", clothes_prices["socks"])
# Out:
# socks costs: 7.99

# %%
clothes_prices["tie"] = 12.50

# %%
print(f"updated clothes prices: {clothes_prices}")
# Out:
# updated clothes prices: {'shoes': 29.99, 'jeans': 19.99, 'socks': 7.99, 'tie': 12.5}

# %%
clothes_prices["boxers"] = 5.25

# %%
print(f"updated clothes prices: {clothes_prices}")
# Out:
# updated clothes prices: {'shoes': 29.99, 'jeans': 19.99, 'socks': 7.99, 'tie': 12.5, 'boxers': 5.25}

# %%
total_cost = sum(clothes_prices.values())

# %% [raw]
# print("Total cost:", total_cost)

# %%
print(clothes_prices)
# Out:
# {'shoes': 29.99, 'jeans': 19.99, 'socks': 7.99, 'tie': 12.5, 'boxers': 5.25}

# %%
print(sum(clothes_prices.values()))
# Out:
# 75.72
